# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

import importlib
import SVM_augmented
import plot_SVM
import Load_Data

importlib.reload(SVM_augmented)
importlib.reload(plot_SVM)
importlib.reload(Load_Data)
# Out:
# <module 'Load_Data' from 'd:\\education\\sem 9 SIGMA\\convex optimization\\lab 2\\code\\Load_Data.py'>

# %%
X,y = Load_Data.Load_Data_mnist()

def plot_data(X,y):
    index1 = np.where(y==1)[0]
    index2 = np.where(y==-1)[0]
    X_class1 = X[:,index1]
    X_class2 = X[:,index2]
    plt.scatter(X_class1[0],X_class1[1],c='red')
    plt.scatter(X_class2[0],X_class2[1])

pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X.T)
print("X_reduced of shape:",X_reduced.shape)
plot_data(X_reduced.T,y)
# Out:
# y of shape: (12665,)
# X of shape: (784, 12665)
# X_reduced of shape: (12665, 2)

# %%
# Example usage
if __name__ == "__main__":
    # Solve SVM using augmented Lagrangian
    w, b, lambda_SV = SVM_augmented.Train_SVM(X_reduced, y, eta=1.0, rho=1.0, max_iter=1000)

    print("Optimal weight vector (w):", w)
    print("Optimal bias (b):", b)

    # Plot the data and decision boundary
    plot_SVM.plot_svm_decision_boundary(X_reduced, y, w, b)
# Out:
# Optimal weight vector (w): [-192.38996383  -28.54823954]
# Optimal bias (b): -0.5660002881546493
